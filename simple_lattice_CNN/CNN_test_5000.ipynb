# %% [markdown]
# # fit same smaller CNN used for test on 5000 training images

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import re
import os
import sys
import shutil
from shutil import copyfile, copy2
from shutil import move

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
from scipy import stats
# Cause plots to be displayed in the notebook:
# %matplotlib inline

# %%
import subprocess

# %%
from matplotlib import cm
from latt2D_modules import calc_diffuse
from latt2D_modules import get_occ_map, get_2D_occ_map_from_seq,store_occ_map_as_seq
from latt2D_modules import plot_occ_map,read_bin,output_16bit_pgm
import time

# %%
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# 2023-05-09 06:23:10.461622: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from keras.metrics import MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError, RootMeanSquaredError
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import h5py
from keras.callbacks import ModelCheckpoint

# %%
# read in all the correlation datum  
df1=pd.read_csv('output_correlations_1000.csv')
df2=pd.read_csv('output_correlations_2000.csv')
df3=pd.read_csv('output_correlations_3000.csv')
df_corfu=pd.concat([df1,df2,df3],axis=0)
df_corfu=df_corfu.drop('Unnamed: 0',axis=1)
df_corfu.reset_index(inplace=True,drop=True)

# %%
y=df_corfu.iloc[:,1:4].values
my_cols=df_corfu.columns.values[1:]
my_cols
# Out:
# array(['01', '10', '11'], dtype=object)

# %%
palette = sns.color_palette("Set2", n_colors=3)
rows,cols =1,3 
fig, axes = plt.subplots(rows, cols, figsize=(12,3))
k=0
for i in range(rows): 
    for j in range(cols):
        mycol=my_cols[k]
        sns.histplot(ax=axes[j], data=df_corfu, x=mycol, bins=50,color=palette[k] , kde=True, stat='density', label='%s'%mycol )
        axes[j].set_xlabel(None)
        axes[j].set_ylabel(None)
        axes[j].set_xlim([-1,1])
        axes[j].legend(loc=1)
        k+=1

fig.suptitle("Density distributions of the randomly generated target CFS2 variables used for CNN fit.", fontsize=12, y=0.98)
plt.subplots_adjust(left=0.1,
                    bottom=0.1,
                    right=0.9,
                    top=0.9,
                    wspace=0.3,
                    hspace=0.2)
# plt.legend()

# %%
# Open the HDF5 file in read-only mode
with h5py.File('image_dataset_5000.h5', 'r') as f:
    # Get a list of dataset names in the HDF5 file
    dataset_names = list(f.keys())
    
    # Print the names of all datasets
    for name in dataset_names:
        print(name)
    dset=f['img_data']
    X=dset[:]
# Out:
# img_data

# %% [raw]
# # old code to read data directly from binfiles
# N=10 # rad this many images
# Nstart=0 # start labels here
# imdats=[]
# for i in range(N):
#     imb = read_bin('./image_inputs_bin/hk0_%s.bin'%str(i+Nstart).zfill(6), npixels=64, offset=1280)
#     imdats.append(imb)
# imdats=np.vstack(imdats)
# imdats=imdats.reshape((10,64,64))
# print(np.shape(imdats))

# %%
print(np.shape(y))
print(np.shape(X))
# Out:
# (5000, 3)
# (5000, 64, 64)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.2)

# %%
X_train=np.expand_dims(X_train, -1)
X_test=np.expand_dims(X_test, -1)

# %%
print(np.shape(X_train),type(X_train))
print(np.shape(X_test),type(X_test))
print(np.shape(y_train),type(y_train))
print(np.shape(y_test),type(y_test))
# Out:
# (4000, 64, 64, 1) <class 'numpy.ndarray'>
# (1000, 64, 64, 1) <class 'numpy.ndarray'>
# (4000, 3) <class 'numpy.ndarray'>
# (1000, 3) <class 'numpy.ndarray'>

# %% [raw]
# imshow(np.flip(imdats[4],0),cmap='gray')

# %% [raw]
# ax=plt.hist(imdats[0].flatten(),bins=64)

# %% [raw]
# scaler=StandardScaler()
# X=scaler.fit_transform(imdats.reshape((10,-1)))
# np.shape(X)

# %% [raw]
# ax=plt.hist(X[0],bins=64)
# imshow(np.flip(X[0].reshape((64,64)),0),cmap='gray')

# %%
input_shape = (64, 64, 1)
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu",name='conv1'),
        layers.BatchNormalization(name='norm1'),
        layers.MaxPooling2D(pool_size=(2, 2),name='maxpool1'),
        layers.Dropout(0.2,name='drop1'),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu",name='conv2'),
        layers.BatchNormalization(name='norm2'),
        layers.MaxPooling2D(pool_size=(2, 2),name='maxpool2'),
        layers.Flatten(name='flatten1'),
        layers.Dropout(0.5,name='drop2'),
        layers.Dense(3, activation="linear",name='dense_out'),
    ],name='seq_CNN'
)

model.summary()
# Out:
# Model: "seq_CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 62, 62, 32)        320
#
#  norm1 (BatchNormalization)  (None, 62, 62, 32)        128
#
#  maxpool1 (MaxPooling2D)     (None, 31, 31, 32)        0
#
#  drop1 (Dropout)             (None, 31, 31, 32)        0
#
#  conv2 (Conv2D)              (None, 29, 29, 64)        18496
#
#  norm2 (BatchNormalization)  (None, 29, 29, 64)        256
#
#  maxpool2 (MaxPooling2D)     (None, 14, 14, 64)        0
#
#  flatten1 (Flatten)          (None, 12544)             0
#
#  drop2 (Dropout)             (None, 12544)             0
#
#  dense_out (Dense)           (None, 3)                 37635
#
# =================================================================
# Total params: 56,835
# Trainable params: 56,643
# Non-trainable params: 192
# _________________________________________________________________
# 2023-05-09 06:23:37.307837: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-09 06:23:37.309874: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
# Load the saved weights into the model
# model.load_weights('best_model.h5')

# %%
batch_size = 32
epochs = 100
# Define checkpoint callback
checkpoint = ModelCheckpoint('best_model_5000.h5', monitor='val_loss', save_best_only=True, mode='min', verbose=1)
# opt = keras.optimizers.Adam(learning_rate=0.01) # not using this atm
model.compile(loss="mse", optimizer="adam", metrics=[MeanSquaredError(),MeanAbsoluteError()])
# metrics=[ MeanSquaredError(), MeanAbsoluteError()]

# %%
history =model.fit(X_train,y_train,batch_size=batch_size, epochs=epochs, validation_split=0.2,callbacks=[checkpoint])

# ## Evaluate the trained model

# In[ ]:
# Out:
# Epoch 1/100
#  99/100 [============================>.] - ETA: 0s - loss: 9.3308 - mean_squared_error: 9.3308 - mean_absolute_error: 2.1956
# Epoch 1: val_loss improved from inf to 0.26397, saving model to best_model_5000.h5
# 100/100 [==============================] - 5s 42ms/step - loss: 9.3396 - mean_squared_error: 9.3396 - mean_absolute_error: 2.1974 - val_loss: 0.2640 - val_mean_squared_error: 0.2640 - val_mean_absolute_error: 0.4073
# Epoch 2/100
#  99/100 [============================>.] - ETA: 0s - loss: 5.6405 - mean_squared_error: 5.6405 - mean_absolute_error: 1.7499
# Epoch 2: val_loss did not improve from 0.26397
# 100/100 [==============================] - 6s 64ms/step - loss: 5.6405 - mean_squared_error: 5.6405 - mean_absolute_error: 1.7502 - val_loss: 0.2770 - val_mean_squared_error: 0.2770 - val_mean_absolute_error: 0.4138
# Epoch 3/100
#  99/100 [============================>.] - ETA: 0s - loss: 3.7801 - mean_squared_error: 3.7801 - mean_absolute_error: 1.4518
# Epoch 3: val_loss did not improve from 0.26397
# 100/100 [==============================] - 4s 43ms/step - loss: 3.7852 - mean_squared_error: 3.7852 - mean_absolute_error: 1.4533 - val_loss: 0.3479 - val_mean_squared_error: 0.3479 - val_mean_absolute_error: 0.4485
# Epoch 4/100
# 100/100 [==============================] - ETA: 0s - loss: 3.1371 - mean_squared_error: 3.1371 - mean_absolute_error: 1.3266
# Epoch 4: val_loss did not improve from 0.26397
# 100/100 [==============================] - 5s 48ms/step - loss: 3.1371 - mean_squared_error: 3.1371 - mean_absolute_error: 1.3266 - val_loss: 0.3726 - val_mean_squared_error: 0.3726 - val_mean_absolute_error: 0.4684
# Epoch 5/100
# 100/100 [==============================] - ETA: 0s - loss: 2.3593 - mean_squared_error: 2.3593 - mean_absolute_error: 1.1592
# Epoch 5: val_loss did not improve from 0.26397
# 100/100 [==============================] - 4s 45ms/step - loss: 2.3593 - mean_squared_error: 2.3593 - mean_absolute_error: 1.1592 - val_loss: 0.5058 - val_mean_squared_error: 0.5058 - val_mean_absolute_error: 0.5507
# Epoch 6/100
# 100/100 [==============================] - ETA: 0s - loss: 1.8565 - mean_squared_error: 1.8565 - mean_absolute_error: 1.0364
# Epoch 6: val_loss did not improve from 0.26397
# 100/100 [==============================] - 7s 66ms/step - loss: 1.8565 - mean_squared_error: 1.8565 - mean_absolute_error: 1.0364 - val_loss: 0.3498 - val_mean_squared_error: 0.3498 - val_mean_absolute_error: 0.4460
# Epoch 7/100
# 100/100 [==============================] - ETA: 0s - loss: 1.5391 - mean_squared_error: 1.5391 - mean_absolute_error: 0.9316
# Epoch 7: val_loss did not improve from 0.26397
# 100/100 [==============================] - 7s 71ms/step - loss: 1.5391 - mean_squared_error: 1.5391 - mean_absolute_error: 0.9316 - val_loss: 0.2794 - val_mean_squared_error: 0.2794 - val_mean_absolute_error: 0.3860
# Epoch 8/100
# 100/100 [==============================] - ETA: 0s - loss: 1.1852 - mean_squared_error: 1.1852 - mean_absolute_error: 0.8209
# Epoch 8: val_loss did not improve from 0.26397
# 100/100 [==============================] - 7s 68ms/step - loss: 1.1852 - mean_squared_error: 1.1852 - mean_absolute_error: 0.8209 - val_loss: 0.2973 - val_mean_squared_error: 0.2973 - val_mean_absolute_error: 0.4149
# Epoch 9/100
# 100/100 [==============================] - ETA: 0s - loss: 0.9332 - mean_squared_error: 0.9332 - mean_absolute_error: 0.7336
# Epoch 9: val_loss did not improve from 0.26397
# 100/100 [==============================] - 3s 32ms/step - loss: 0.9332 - mean_squared_error: 0.9332 - mean_absolute_error: 0.7336 - val_loss: 0.4744 - val_mean_squared_error: 0.4744 - val_mean_absolute_error: 0.5714
# Epoch 10/100
# 100/100 [==============================] - ETA: 0s - loss: 0.8347 - mean_squared_error: 0.8347 - mean_absolute_error: 0.6967
# Epoch 10: val_loss improved from 0.26397 to 0.23631, saving model to best_model_5000.h5
# 100/100 [==============================] - 3s 30ms/step - loss: 0.8347 - mean_squared_error: 0.8347 - mean_absolute_error: 0.6967 - val_loss: 0.2363 - val_mean_squared_error: 0.2363 - val_mean_absolute_error: 0.3681
# Epoch 11/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.6779 - mean_squared_error: 0.6779 - mean_absolute_error: 0.6255
# Epoch 11: val_loss did not improve from 0.23631
# 100/100 [==============================] - 3s 32ms/step - loss: 0.6760 - mean_squared_error: 0.6760 - mean_absolute_error: 0.6244 - val_loss: 0.2431 - val_mean_squared_error: 0.2431 - val_mean_absolute_error: 0.3801
# Epoch 12/100
# 100/100 [==============================] - ETA: 0s - loss: 0.5912 - mean_squared_error: 0.5912 - mean_absolute_error: 0.5824
# Epoch 12: val_loss did not improve from 0.23631
# 100/100 [==============================] - 7s 68ms/step - loss: 0.5912 - mean_squared_error: 0.5912 - mean_absolute_error: 0.5824 - val_loss: 0.2626 - val_mean_squared_error: 0.2626 - val_mean_absolute_error: 0.3797
# Epoch 13/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.4588 - mean_squared_error: 0.4588 - mean_absolute_error: 0.5168
# Epoch 13: val_loss improved from 0.23631 to 0.09388, saving model to best_model_5000.h5
# 100/100 [==============================] - 5s 46ms/step - loss: 0.4581 - mean_squared_error: 0.4581 - mean_absolute_error: 0.5161 - val_loss: 0.0939 - val_mean_squared_error: 0.0939 - val_mean_absolute_error: 0.2333
# Epoch 14/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3712 - mean_squared_error: 0.3712 - mean_absolute_error: 0.4646
# Epoch 14: val_loss improved from 0.09388 to 0.06444, saving model to best_model_5000.h5
# 100/100 [==============================] - 4s 39ms/step - loss: 0.3712 - mean_squared_error: 0.3712 - mean_absolute_error: 0.4646 - val_loss: 0.0644 - val_mean_squared_error: 0.0644 - val_mean_absolute_error: 0.1871
# Epoch 15/100
# 100/100 [==============================] - ETA: 0s - loss: 0.3101 - mean_squared_error: 0.3101 - mean_absolute_error: 0.4245
# Epoch 15: val_loss did not improve from 0.06444
# 100/100 [==============================] - 5s 49ms/step - loss: 0.3101 - mean_squared_error: 0.3101 - mean_absolute_error: 0.4245 - val_loss: 0.1070 - val_mean_squared_error: 0.1070 - val_mean_absolute_error: 0.2582
# Epoch 16/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2875 - mean_squared_error: 0.2875 - mean_absolute_error: 0.4041
# Epoch 16: val_loss did not improve from 0.06444
# 100/100 [==============================] - 10s 101ms/step - loss: 0.2875 - mean_squared_error: 0.2875 - mean_absolute_error: 0.4041 - val_loss: 0.1041 - val_mean_squared_error: 0.1041 - val_mean_absolute_error: 0.2427
# Epoch 17/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2382 - mean_squared_error: 0.2382 - mean_absolute_error: 0.3676
# Epoch 17: val_loss did not improve from 0.06444
# 100/100 [==============================] - 7s 70ms/step - loss: 0.2377 - mean_squared_error: 0.2377 - mean_absolute_error: 0.3675 - val_loss: 0.0963 - val_mean_squared_error: 0.0963 - val_mean_absolute_error: 0.2456
# Epoch 18/100
# 100/100 [==============================] - ETA: 0s - loss: 0.2192 - mean_squared_error: 0.2192 - mean_absolute_error: 0.3529
# Epoch 18: val_loss did not improve from 0.06444
# 100/100 [==============================] - 9s 93ms/step - loss: 0.2192 - mean_squared_error: 0.2192 - mean_absolute_error: 0.3529 - val_loss: 0.0710 - val_mean_squared_error: 0.0710 - val_mean_absolute_error: 0.2013
# Epoch 19/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1799 - mean_squared_error: 0.1799 - mean_absolute_error: 0.3223
# Epoch 19: val_loss improved from 0.06444 to 0.04200, saving model to best_model_5000.h5
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1799 - mean_squared_error: 0.1799 - mean_absolute_error: 0.3223 - val_loss: 0.0420 - val_mean_squared_error: 0.0420 - val_mean_absolute_error: 0.1605
# Epoch 20/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1602 - mean_squared_error: 0.1602 - mean_absolute_error: 0.3066
# Epoch 20: val_loss did not improve from 0.04200
# 100/100 [==============================] - 8s 79ms/step - loss: 0.1602 - mean_squared_error: 0.1602 - mean_absolute_error: 0.3066 - val_loss: 0.0510 - val_mean_squared_error: 0.0510 - val_mean_absolute_error: 0.1732
# Epoch 21/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1470 - mean_squared_error: 0.1470 - mean_absolute_error: 0.2913
# Epoch 21: val_loss did not improve from 0.04200
# 100/100 [==============================] - 8s 85ms/step - loss: 0.1470 - mean_squared_error: 0.1470 - mean_absolute_error: 0.2913 - val_loss: 0.0429 - val_mean_squared_error: 0.0429 - val_mean_absolute_error: 0.1544
# Epoch 22/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1216 - mean_squared_error: 0.1216 - mean_absolute_error: 0.2636
# Epoch 22: val_loss did not improve from 0.04200
# 100/100 [==============================] - 11s 110ms/step - loss: 0.1216 - mean_squared_error: 0.1216 - mean_absolute_error: 0.2636 - val_loss: 0.0517 - val_mean_squared_error: 0.0517 - val_mean_absolute_error: 0.1809
# Epoch 23/100
# 100/100 [==============================] - ETA: 0s - loss: 0.1083 - mean_squared_error: 0.1083 - mean_absolute_error: 0.2506
# Epoch 23: val_loss improved from 0.04200 to 0.02629, saving model to best_model_5000.h5
# 100/100 [==============================] - 10s 99ms/step - loss: 0.1083 - mean_squared_error: 0.1083 - mean_absolute_error: 0.2506 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.1264
# Epoch 24/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0890 - mean_squared_error: 0.0890 - mean_absolute_error: 0.2280
# Epoch 24: val_loss improved from 0.02629 to 0.01840, saving model to best_model_5000.h5
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0890 - mean_squared_error: 0.0890 - mean_absolute_error: 0.2280 - val_loss: 0.0184 - val_mean_squared_error: 0.0184 - val_mean_absolute_error: 0.1007
# Epoch 25/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0835 - mean_squared_error: 0.0835 - mean_absolute_error: 0.2207
# Epoch 25: val_loss did not improve from 0.01840
# 100/100 [==============================] - 7s 70ms/step - loss: 0.0835 - mean_squared_error: 0.0835 - mean_absolute_error: 0.2207 - val_loss: 0.0272 - val_mean_squared_error: 0.0272 - val_mean_absolute_error: 0.1303
# Epoch 26/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0835 - mean_squared_error: 0.0835 - mean_absolute_error: 0.2209
# Epoch 26: val_loss did not improve from 0.01840
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0835 - mean_squared_error: 0.0835 - mean_absolute_error: 0.2209 - val_loss: 0.0324 - val_mean_squared_error: 0.0324 - val_mean_absolute_error: 0.1348
# Epoch 27/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0749 - mean_squared_error: 0.0749 - mean_absolute_error: 0.2070
# Epoch 27: val_loss did not improve from 0.01840
# 100/100 [==============================] - 8s 77ms/step - loss: 0.0749 - mean_squared_error: 0.0749 - mean_absolute_error: 0.2070 - val_loss: 0.0302 - val_mean_squared_error: 0.0302 - val_mean_absolute_error: 0.1356
# Epoch 28/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0683 - mean_squared_error: 0.0683 - mean_absolute_error: 0.1994
# Epoch 28: val_loss did not improve from 0.01840
# 100/100 [==============================] - 8s 77ms/step - loss: 0.0683 - mean_squared_error: 0.0683 - mean_absolute_error: 0.1994 - val_loss: 0.0273 - val_mean_squared_error: 0.0273 - val_mean_absolute_error: 0.1296
# Epoch 29/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0600 - mean_squared_error: 0.0600 - mean_absolute_error: 0.1857
# Epoch 29: val_loss did not improve from 0.01840
# 100/100 [==============================] - 8s 77ms/step - loss: 0.0600 - mean_squared_error: 0.0600 - mean_absolute_error: 0.1857 - val_loss: 0.0245 - val_mean_squared_error: 0.0245 - val_mean_absolute_error: 0.1212
# Epoch 30/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.0617 - mean_squared_error: 0.0617 - mean_absolute_error: 0.1898
# Epoch 30: val_loss did not improve from 0.01840
# 100/100 [==============================] - 4s 43ms/step - loss: 0.0619 - mean_squared_error: 0.0619 - mean_absolute_error: 0.1901 - val_loss: 0.0653 - val_mean_squared_error: 0.0653 - val_mean_absolute_error: 0.1984
# Epoch 31/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.0665 - mean_squared_error: 0.0665 - mean_absolute_error: 0.1972
# Epoch 31: val_loss did not improve from 0.01840
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0664 - mean_squared_error: 0.0664 - mean_absolute_error: 0.1970 - val_loss: 0.0335 - val_mean_squared_error: 0.0335 - val_mean_absolute_error: 0.1340
# Epoch 32/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0538 - mean_squared_error: 0.0538 - mean_absolute_error: 0.1763
# Epoch 32: val_loss did not improve from 0.01840
# 100/100 [==============================] - 9s 87ms/step - loss: 0.0538 - mean_squared_error: 0.0538 - mean_absolute_error: 0.1763 - val_loss: 0.0188 - val_mean_squared_error: 0.0188 - val_mean_absolute_error: 0.1026
# Epoch 33/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0527 - mean_squared_error: 0.0527 - mean_absolute_error: 0.1756
# Epoch 33: val_loss did not improve from 0.01840
# 100/100 [==============================] - 7s 65ms/step - loss: 0.0527 - mean_squared_error: 0.0527 - mean_absolute_error: 0.1756 - val_loss: 0.0281 - val_mean_squared_error: 0.0281 - val_mean_absolute_error: 0.1280
# Epoch 34/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0503 - mean_squared_error: 0.0503 - mean_absolute_error: 0.1718
# Epoch 34: val_loss did not improve from 0.01840
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0503 - mean_squared_error: 0.0503 - mean_absolute_error: 0.1718 - val_loss: 0.0234 - val_mean_squared_error: 0.0234 - val_mean_absolute_error: 0.1100
# Epoch 35/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.0542 - mean_squared_error: 0.0542 - mean_absolute_error: 0.1771
# Epoch 35: val_loss improved from 0.01840 to 0.01491, saving model to best_model_5000.h5
# 100/100 [==============================] - 5s 46ms/step - loss: 0.0541 - mean_squared_error: 0.0541 - mean_absolute_error: 0.1770 - val_loss: 0.0149 - val_mean_squared_error: 0.0149 - val_mean_absolute_error: 0.0945
# Epoch 36/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.0497 - mean_squared_error: 0.0497 - mean_absolute_error: 0.1712
# Epoch 36: val_loss did not improve from 0.01491
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0496 - mean_squared_error: 0.0496 - mean_absolute_error: 0.1712 - val_loss: 0.0234 - val_mean_squared_error: 0.0234 - val_mean_absolute_error: 0.1215
# Epoch 37/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.0470 - mean_squared_error: 0.0470 - mean_absolute_error: 0.1666
# Epoch 37: val_loss did not improve from 0.01491
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0472 - mean_squared_error: 0.0472 - mean_absolute_error: 0.1668 - val_loss: 0.0215 - val_mean_squared_error: 0.0215 - val_mean_absolute_error: 0.1169
# Epoch 38/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0574 - mean_squared_error: 0.0574 - mean_absolute_error: 0.1807
# Epoch 38: val_loss did not improve from 0.01491
# 100/100 [==============================] - 4s 42ms/step - loss: 0.0574 - mean_squared_error: 0.0574 - mean_absolute_error: 0.1807 - val_loss: 0.0271 - val_mean_squared_error: 0.0271 - val_mean_absolute_error: 0.1218
# Epoch 39/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0546 - mean_squared_error: 0.0546 - mean_absolute_error: 0.1789
# Epoch 39: val_loss did not improve from 0.01491
# 100/100 [==============================] - 7s 74ms/step - loss: 0.0546 - mean_squared_error: 0.0546 - mean_absolute_error: 0.1789 - val_loss: 0.0243 - val_mean_squared_error: 0.0243 - val_mean_absolute_error: 0.1147
# Epoch 40/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0509 - mean_squared_error: 0.0509 - mean_absolute_error: 0.1708
# Epoch 40: val_loss did not improve from 0.01491
# 100/100 [==============================] - 7s 69ms/step - loss: 0.0509 - mean_squared_error: 0.0509 - mean_absolute_error: 0.1708 - val_loss: 0.0167 - val_mean_squared_error: 0.0167 - val_mean_absolute_error: 0.1013
# Epoch 41/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.0532 - mean_squared_error: 0.0532 - mean_absolute_error: 0.1765
# Epoch 41: val_loss did not improve from 0.01491
# 100/100 [==============================] - 4s 42ms/step - loss: 0.0532 - mean_squared_error: 0.0532 - mean_absolute_error: 0.1765 - val_loss: 0.0247 - val_mean_squared_error: 0.0247 - val_mean_absolute_error: 0.1174
# Epoch 42/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.0459 - mean_squared_error: 0.0459 - mean_absolute_error: 0.1633
# Epoch 42: val_loss did not improve from 0.01491
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0458 - mean_squared_error: 0.0458 - mean_absolute_error: 0.1631 - val_loss: 0.0167 - val_mean_squared_error: 0.0167 - val_mean_absolute_error: 0.1015
# Epoch 43/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.0455 - mean_squared_error: 0.0455 - mean_absolute_error: 0.1639
# Epoch 43: val_loss did not improve from 0.01491
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0455 - mean_squared_error: 0.0455 - mean_absolute_error: 0.1641 - val_loss: 0.0222 - val_mean_squared_error: 0.0222 - val_mean_absolute_error: 0.1159
# Epoch 44/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0406 - mean_squared_error: 0.0406 - mean_absolute_error: 0.1537
# Epoch 44: val_loss did not improve from 0.01491
# 100/100 [==============================] - 8s 79ms/step - loss: 0.0406 - mean_squared_error: 0.0406 - mean_absolute_error: 0.1537 - val_loss: 0.0170 - val_mean_squared_error: 0.0170 - val_mean_absolute_error: 0.0979
# Epoch 45/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0434 - mean_squared_error: 0.0434 - mean_absolute_error: 0.1592
# Epoch 45: val_loss did not improve from 0.01491
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0434 - mean_squared_error: 0.0434 - mean_absolute_error: 0.1592 - val_loss: 0.0226 - val_mean_squared_error: 0.0226 - val_mean_absolute_error: 0.1157
# Epoch 46/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0408 - mean_squared_error: 0.0408 - mean_absolute_error: 0.1556
# Epoch 46: val_loss did not improve from 0.01491
# 100/100 [==============================] - 7s 68ms/step - loss: 0.0408 - mean_squared_error: 0.0408 - mean_absolute_error: 0.1556 - val_loss: 0.0186 - val_mean_squared_error: 0.0186 - val_mean_absolute_error: 0.1063
# Epoch 47/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0382 - mean_squared_error: 0.0382 - mean_absolute_error: 0.1501
# Epoch 47: val_loss did not improve from 0.01491
# 100/100 [==============================] - 7s 69ms/step - loss: 0.0382 - mean_squared_error: 0.0382 - mean_absolute_error: 0.1501 - val_loss: 0.0178 - val_mean_squared_error: 0.0178 - val_mean_absolute_error: 0.1041
# Epoch 48/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0387 - mean_squared_error: 0.0387 - mean_absolute_error: 0.1489
# Epoch 48: val_loss improved from 0.01491 to 0.01291, saving model to best_model_5000.h5
# 100/100 [==============================] - 7s 70ms/step - loss: 0.0387 - mean_squared_error: 0.0387 - mean_absolute_error: 0.1489 - val_loss: 0.0129 - val_mean_squared_error: 0.0129 - val_mean_absolute_error: 0.0895
# Epoch 49/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0306 - mean_squared_error: 0.0306 - mean_absolute_error: 0.1338
# Epoch 49: val_loss did not improve from 0.01291
# 100/100 [==============================] - 7s 72ms/step - loss: 0.0306 - mean_squared_error: 0.0306 - mean_absolute_error: 0.1338 - val_loss: 0.0157 - val_mean_squared_error: 0.0157 - val_mean_absolute_error: 0.0997
# Epoch 50/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1244
# Epoch 50: val_loss did not improve from 0.01291
# 100/100 [==============================] - 7s 71ms/step - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1244 - val_loss: 0.0142 - val_mean_squared_error: 0.0142 - val_mean_absolute_error: 0.0917
# Epoch 51/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0229 - mean_squared_error: 0.0229 - mean_absolute_error: 0.1156
# Epoch 51: val_loss improved from 0.01291 to 0.00707, saving model to best_model_5000.h5
# 100/100 [==============================] - 7s 73ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - mean_absolute_error: 0.1156 - val_loss: 0.0071 - val_mean_squared_error: 0.0071 - val_mean_absolute_error: 0.0651
# Epoch 52/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0195 - mean_squared_error: 0.0195 - mean_absolute_error: 0.1067
# Epoch 52: val_loss did not improve from 0.00707
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0195 - mean_squared_error: 0.0195 - mean_absolute_error: 0.1067 - val_loss: 0.0076 - val_mean_squared_error: 0.0076 - val_mean_absolute_error: 0.0687
# Epoch 53/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0171 - mean_squared_error: 0.0171 - mean_absolute_error: 0.1007
# Epoch 53: val_loss improved from 0.00707 to 0.00487, saving model to best_model_5000.h5
# 100/100 [==============================] - 7s 74ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - mean_absolute_error: 0.1007 - val_loss: 0.0049 - val_mean_squared_error: 0.0049 - val_mean_absolute_error: 0.0542
# Epoch 54/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0161 - mean_squared_error: 0.0161 - mean_absolute_error: 0.0980
# Epoch 54: val_loss did not improve from 0.00487
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - mean_absolute_error: 0.0980 - val_loss: 0.0068 - val_mean_squared_error: 0.0068 - val_mean_absolute_error: 0.0632
# Epoch 55/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0144 - mean_squared_error: 0.0144 - mean_absolute_error: 0.0924
# Epoch 55: val_loss did not improve from 0.00487
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - mean_absolute_error: 0.0924 - val_loss: 0.0050 - val_mean_squared_error: 0.0050 - val_mean_absolute_error: 0.0544
# Epoch 56/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0135 - mean_squared_error: 0.0135 - mean_absolute_error: 0.0889
# Epoch 56: val_loss did not improve from 0.00487
# 100/100 [==============================] - 8s 79ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - mean_absolute_error: 0.0889 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - val_mean_absolute_error: 0.0747
# Epoch 57/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0835
# Epoch 57: val_loss improved from 0.00487 to 0.00455, saving model to best_model_5000.h5
# 100/100 [==============================] - 7s 69ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0835 - val_loss: 0.0046 - val_mean_squared_error: 0.0046 - val_mean_absolute_error: 0.0521
# Epoch 58/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0114 - mean_squared_error: 0.0114 - mean_absolute_error: 0.0819
# Epoch 58: val_loss improved from 0.00455 to 0.00350, saving model to best_model_5000.h5
# 100/100 [==============================] - 7s 72ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - mean_absolute_error: 0.0819 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - val_mean_absolute_error: 0.0458
# Epoch 59/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0106 - mean_squared_error: 0.0106 - mean_absolute_error: 0.0785
# Epoch 59: val_loss improved from 0.00350 to 0.00227, saving model to best_model_5000.h5
# 100/100 [==============================] - 11s 113ms/step - loss: 0.0106 - mean_squared_error: 0.0106 - mean_absolute_error: 0.0785 - val_loss: 0.0023 - val_mean_squared_error: 0.0023 - val_mean_absolute_error: 0.0377
# Epoch 60/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0116 - mean_squared_error: 0.0116 - mean_absolute_error: 0.0826
# Epoch 60: val_loss did not improve from 0.00227
# 100/100 [==============================] - 11s 114ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - mean_absolute_error: 0.0826 - val_loss: 0.0048 - val_mean_squared_error: 0.0048 - val_mean_absolute_error: 0.0532
# Epoch 61/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0095 - mean_squared_error: 0.0095 - mean_absolute_error: 0.0753
# Epoch 61: val_loss did not improve from 0.00227
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - mean_absolute_error: 0.0753 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - val_mean_absolute_error: 0.0450
# Epoch 62/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0084 - mean_squared_error: 0.0084 - mean_absolute_error: 0.0710
# Epoch 62: val_loss did not improve from 0.00227
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - mean_absolute_error: 0.0710 - val_loss: 0.0045 - val_mean_squared_error: 0.0045 - val_mean_absolute_error: 0.0537
# Epoch 63/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0083 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0702
# Epoch 63: val_loss did not improve from 0.00227
# 100/100 [==============================] - 6s 65ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0702 - val_loss: 0.0038 - val_mean_squared_error: 0.0038 - val_mean_absolute_error: 0.0485
# Epoch 64/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0080 - mean_squared_error: 0.0080 - mean_absolute_error: 0.0692
# Epoch 64: val_loss did not improve from 0.00227
# 100/100 [==============================] - 7s 70ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - mean_absolute_error: 0.0692 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - val_mean_absolute_error: 0.0810
# Epoch 65/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0075 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0664
# Epoch 65: val_loss did not improve from 0.00227
# 100/100 [==============================] - 7s 72ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0664 - val_loss: 0.0025 - val_mean_squared_error: 0.0025 - val_mean_absolute_error: 0.0402
# Epoch 66/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0066 - mean_squared_error: 0.0066 - mean_absolute_error: 0.0627
# Epoch 66: val_loss improved from 0.00227 to 0.00201, saving model to best_model_5000.h5
# 100/100 [==============================] - 7s 70ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - mean_absolute_error: 0.0627 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0350
# Epoch 67/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0053 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0568
# Epoch 67: val_loss did not improve from 0.00201
# 100/100 [==============================] - 7s 70ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0568 - val_loss: 0.0025 - val_mean_squared_error: 0.0025 - val_mean_absolute_error: 0.0402
# Epoch 68/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0053 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0568
# Epoch 68: val_loss improved from 0.00201 to 0.00173, saving model to best_model_5000.h5
# 100/100 [==============================] - 8s 84ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0568 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - val_mean_absolute_error: 0.0317
# Epoch 69/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0050 - mean_squared_error: 0.0050 - mean_absolute_error: 0.0548
# Epoch 69: val_loss did not improve from 0.00173
# 100/100 [==============================] - 7s 70ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - mean_absolute_error: 0.0548 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - val_mean_absolute_error: 0.0360
# Epoch 70/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0055 - mean_squared_error: 0.0055 - mean_absolute_error: 0.0574
# Epoch 70: val_loss improved from 0.00173 to 0.00171, saving model to best_model_5000.h5
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - mean_absolute_error: 0.0574 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - val_mean_absolute_error: 0.0328
# Epoch 71/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0046 - mean_squared_error: 0.0046 - mean_absolute_error: 0.0525
# Epoch 71: val_loss improved from 0.00171 to 0.00170, saving model to best_model_5000.h5
# 100/100 [==============================] - 7s 67ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - mean_absolute_error: 0.0525 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - val_mean_absolute_error: 0.0326
# Epoch 72/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0049 - mean_squared_error: 0.0049 - mean_absolute_error: 0.0544
# Epoch 72: val_loss did not improve from 0.00170
# 100/100 [==============================] - 9s 86ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - mean_absolute_error: 0.0544 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - val_mean_absolute_error: 0.0331
# Epoch 73/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0046 - mean_squared_error: 0.0046 - mean_absolute_error: 0.0528
# Epoch 73: val_loss did not improve from 0.00170
# 100/100 [==============================] - 8s 79ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - mean_absolute_error: 0.0528 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - val_mean_absolute_error: 0.0324
# Epoch 74/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0040 - mean_squared_error: 0.0040 - mean_absolute_error: 0.0491
# Epoch 74: val_loss improved from 0.00170 to 0.00134, saving model to best_model_5000.h5
# 100/100 [==============================] - 8s 76ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - mean_absolute_error: 0.0491 - val_loss: 0.0013 - val_mean_squared_error: 0.0013 - val_mean_absolute_error: 0.0289
# Epoch 75/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0037 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0471
# Epoch 75: val_loss did not improve from 0.00134
# 100/100 [==============================] - 8s 76ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0471 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - val_mean_absolute_error: 0.0297
# Epoch 76/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0034 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0453
# Epoch 76: val_loss did not improve from 0.00134
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0453 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - val_mean_absolute_error: 0.0297
# Epoch 77/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0034 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0449
# Epoch 77: val_loss did not improve from 0.00134
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0449 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - val_mean_absolute_error: 0.0293
# Epoch 78/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0033 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0445
# Epoch 78: val_loss did not improve from 0.00134
# 100/100 [==============================] - 8s 77ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0445 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - val_mean_absolute_error: 0.0466
# Epoch 79/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0037 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0471
# Epoch 79: val_loss did not improve from 0.00134
# 100/100 [==============================] - 8s 78ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0471 - val_loss: 0.0023 - val_mean_squared_error: 0.0023 - val_mean_absolute_error: 0.0356
# Epoch 80/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0030 - mean_squared_error: 0.0030 - mean_absolute_error: 0.0430
# Epoch 80: val_loss did not improve from 0.00134
# 100/100 [==============================] - 7s 73ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - mean_absolute_error: 0.0430 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - val_mean_absolute_error: 0.0312
# Epoch 81/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0032 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0439
# Epoch 81: val_loss improved from 0.00134 to 0.00123, saving model to best_model_5000.h5
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0439 - val_loss: 0.0012 - val_mean_squared_error: 0.0012 - val_mean_absolute_error: 0.0276
# Epoch 82/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0028 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0411
# Epoch 82: val_loss did not improve from 0.00123
# 100/100 [==============================] - 11s 111ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0411 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - val_mean_absolute_error: 0.0346
# Epoch 83/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0394
# Epoch 83: val_loss improved from 0.00123 to 0.00082, saving model to best_model_5000.h5
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0394 - val_loss: 8.2327e-04 - val_mean_squared_error: 8.2327e-04 - val_mean_absolute_error: 0.0221
# Epoch 84/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0390
# Epoch 84: val_loss did not improve from 0.00082
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0390 - val_loss: 0.0011 - val_mean_squared_error: 0.0011 - val_mean_absolute_error: 0.0261
# Epoch 85/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0023 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0370
# Epoch 85: val_loss did not improve from 0.00082
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0370 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - val_mean_absolute_error: 0.0321
# Epoch 86/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0025 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0389
# Epoch 86: val_loss did not improve from 0.00082
# 100/100 [==============================] - 7s 67ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0389 - val_loss: 8.9573e-04 - val_mean_squared_error: 8.9573e-04 - val_mean_absolute_error: 0.0232
# Epoch 87/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0026 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0397
# Epoch 87: val_loss did not improve from 0.00082
# 100/100 [==============================] - 6s 65ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0397 - val_loss: 0.0022 - val_mean_squared_error: 0.0022 - val_mean_absolute_error: 0.0383
# Epoch 88/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0024 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0384
# Epoch 88: val_loss did not improve from 0.00082
# 100/100 [==============================] - 6s 65ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0384 - val_loss: 0.0011 - val_mean_squared_error: 0.0011 - val_mean_absolute_error: 0.0262
# Epoch 89/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0023 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0377
# Epoch 89: val_loss did not improve from 0.00082
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0377 - val_loss: 0.0013 - val_mean_squared_error: 0.0013 - val_mean_absolute_error: 0.0279
# Epoch 90/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0354
# Epoch 90: val_loss improved from 0.00082 to 0.00074, saving model to best_model_5000.h5
# 100/100 [==============================] - 8s 79ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0354 - val_loss: 7.3794e-04 - val_mean_squared_error: 7.3794e-04 - val_mean_absolute_error: 0.0212
# Epoch 91/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0362
# Epoch 91: val_loss did not improve from 0.00074
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0362 - val_loss: 8.0304e-04 - val_mean_squared_error: 8.0304e-04 - val_mean_absolute_error: 0.0228
# Epoch 92/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0018 - mean_squared_error: 0.0018 - mean_absolute_error: 0.0333
# Epoch 92: val_loss improved from 0.00074 to 0.00069, saving model to best_model_5000.h5
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - mean_absolute_error: 0.0333 - val_loss: 6.9068e-04 - val_mean_squared_error: 6.9068e-04 - val_mean_absolute_error: 0.0205
# Epoch 93/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0346
# Epoch 93: val_loss did not improve from 0.00069
# 100/100 [==============================] - 8s 76ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0346 - val_loss: 7.4858e-04 - val_mean_squared_error: 7.4858e-04 - val_mean_absolute_error: 0.0216
# Epoch 94/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0359
# Epoch 94: val_loss did not improve from 0.00069
# 100/100 [==============================] - 5s 53ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0359 - val_loss: 8.0687e-04 - val_mean_squared_error: 8.0687e-04 - val_mean_absolute_error: 0.0222
# Epoch 95/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0349
# Epoch 95: val_loss did not improve from 0.00069
# 100/100 [==============================] - 4s 43ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0349 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - val_mean_absolute_error: 0.0318
# Epoch 96/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0346
# Epoch 96: val_loss did not improve from 0.00069
# 100/100 [==============================] - 8s 76ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0346 - val_loss: 7.1643e-04 - val_mean_squared_error: 7.1643e-04 - val_mean_absolute_error: 0.0207
# Epoch 97/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0344
# Epoch 97: val_loss did not improve from 0.00069
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0344 - val_loss: 0.0010 - val_mean_squared_error: 0.0010 - val_mean_absolute_error: 0.0261
# Epoch 98/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0349
# Epoch 98: val_loss did not improve from 0.00069
# 100/100 [==============================] - 7s 71ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0349 - val_loss: 8.0490e-04 - val_mean_squared_error: 8.0490e-04 - val_mean_absolute_error: 0.0224
# Epoch 99/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0352
# Epoch 99: val_loss improved from 0.00069 to 0.00067, saving model to best_model_5000.h5
# 100/100 [==============================] - 7s 70ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0352 - val_loss: 6.7095e-04 - val_mean_squared_error: 6.7095e-04 - val_mean_absolute_error: 0.0201
# Epoch 100/100
# 100/100 [==============================] - ETA: 0s - loss: 0.0018 - mean_squared_error: 0.0018 - mean_absolute_error: 0.0333
# Epoch 100: val_loss improved from 0.00067 to 0.00061, saving model to best_model_5000.h5
# 100/100 [==============================] - 7s 74ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - mean_absolute_error: 0.0333 - val_loss: 6.0944e-04 - val_mean_squared_error: 6.0944e-04 - val_mean_absolute_error: 0.0194

# %%
score = model.evaluate(X_test, y_test, verbose=1)
print("Test loss:", score[0])
print("Test mae:", score[2])
# Out:
# 32/32 [==============================] - 1s 36ms/step - loss: 6.5126e-04 - mean_squared_error: 6.5126e-04 - mean_absolute_error: 0.0199
# Test loss: 0.000651259149890393
# Test mae: 0.019871491938829422

# %%
# Plot the training and validation loss as a function of the epoch
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# %%
# Evaluate the model on the test set
y_pred = model.predict(X_test)
r2 = r2_score(y_test.flatten(), y_pred.flatten())
print("Test R2 score:", r2)
# Out:
# 32/32 [==============================] - 1s 18ms/step
# Test R2 score: 0.9970820230804757

# %%
m,b=np.polyfit(y_test.flatten(),y_pred.flatten(),1)
xs=np.linspace(-1,1,10)
ys=m*xs+b

# %%
ax=sns.scatterplot(x=y_test.flatten(),y=y_pred.flatten(),marker='o',edgecolor='b',c='none',s=10,alpha=0.7,label='R2:%.2f'%r2)
ax=plt.plot(xs,ys,c='k',marker='none',linestyle='--',alpha=0.6,label='line fit')
ax=plt.legend()
ax=plt.xlim([-1.0,1.0])
ax=plt.ylim([-1.0,1.0])
ax=plt.margins(0.25)
ax=plt.xlabel('Actual Values')
ax=plt.ylabel('Predicted Values')
ax=plt.title('Predicted vs Actual Values')

# %% [markdown]
# ## done some more EDA on the actual data so that we can get some idea of predictive power but also
# ## exactly how sensitive is the model is to outliers

# %% [markdown]
# ### the below histogram means that any data fed into the model
# ### should roughly scale with the same distribution of intensities
# the best way to do this is might be to just draw a straight line through the logplot version of the histogram
# sicne there is information that is so weak it is less useful

# %%
ax=plt.hist(X.flatten(),bins=1000,log=True,density=True)
print(np.mean(X.flatten()))
print(np.median(X.flatten()))
print(np.max(X.flatten()))
print(np.min(X.flatten()))
# Out:
# 0.251630584576994
# 0.09408986940979958
# 45.67372131347656
# 0.001945657655596733

# %%
iconc=0.50 # spin concentration
cread=0    # reading correlation function from input file  otherwise it will be generated randomly 
'corr.in'
'jswitch.in'
icycles=200  # MC cycles 
ianneal=200  # MC input

# %%
# np.shape(X_test[xvar].reshape((64,-1)))
# ax=imshow(np.flip(X_test[xvar].reshape((64,-1)),0),cmap='gray')

xvar=np.random.randint(0,np.shape(X_test)[0],1)[0]   
y_pred = model.predict(X_test)

y_pred[xvar]
# np.shape(X_test[xvar])
#imshow(np.transpose(occ2d),interpolation='nearest',cmap='gray')
# Out:
# 32/32 [==============================] - 1s 34ms/step
# array([-0.5728368 ,  0.32697698, -0.7401101 ], dtype=float32)

# %%
def get_metrics_ypred_ytest(xvar):
    corr_test=y_test[xvar]
    corr_pred=y_pred[xvar]
    r2y = r2_score(corr_test, corr_pred)
    msey=mean_squared_error(corr_test, corr_pred)
    maey=mean_absolute_error(corr_test, corr_pred)
    return [r2y,msey,maey]

# %%
def get_metrics_compare_regens_test_set(xvar,exp=1):   
    corr_in=y_test[xvar]
    corr_in=np.r_[1.0,corr_in]
    corr_out=np.loadtxt('./expfiles_%d/corr.out'%exp)
    imdat_0 = X_test[xvar].reshape((64,-1))
    imdat_1 = read_bin('./expfiles_%d/hk0.bin'%exp, npixels=64, offset=1280)
    
  #  print(corr_in, corr_out.flatten())
  #  print(np.shape(imdat_0)) 
  #  print(np.shape(imdat_1))
    r2c = r2_score(corr_in.flatten(), corr_out.flatten())
    msec=mean_squared_error(corr_in,corr_out.flatten())
    maec=mean_absolute_error(corr_in,corr_out.flatten())

    r2i=r2_score(imdat_0.flatten(),imdat_1.flatten())
    msei=mean_squared_error(imdat_0.flatten(),imdat_1.flatten())
    maei=mean_absolute_error(imdat_0.flatten(),imdat_1.flatten())
    return [r2c,msec,maec,r2i,msei,maei]    

# get_metrics_compare_regens_test_set(xvar,exp=1)

# %%
# Create a figure and axis for the plot
# Define a function to update the plot
def update_plot_regen(xvar):
    
    rows,cols =1,3 
    fig, axes = plt.subplots(rows, cols, figsize=(6,6))

   
    imdat = X_test[xvar].reshape((64,-1))
    axes[0].imshow(np.flip(imdat,0),cmap='gray')
    axes[0].axis("off")

    corrin=y_test[xvar]
    fhout=open('corr.in','w')
    fhout.write("%.6f %.6f\n%.6f %.6f\n"%(1.0,corrin[0],corrin[1],corrin[2]))
    fhout.close()
    calc_diffuse(iconc,1,icycles,ianneal,1) # do the regen on the image  
    
    occ3D=get_occ_map('./expfiles_1/ising2D_occ.txt')
    axes[1].imshow(np.transpose(occ3D[:,:,0]),interpolation='nearest',cmap='gray') 
    axes[1].axis("off")
    imdat = read_bin('./expfiles_1/hk0.bin', npixels=64, offset=1280)
    axes[2].imshow(np.flip(imdat,0),cmap='gray')
    axes[2].axis("off")
    
    my_metrics=get_metrics_compare_regens_test_set(xvar)
    fig.suptitle(" metrics(r2, mse, mae)\n corrfunc: %.3f, %.3f, %.3f \n FT_metrics: %.3f, %.3f, %.3f " %(tuple(my_metrics)), fontsize=10,y=0.73)

# %%
# Create a figure and axis for the plot
# Define a function to update the plot
def update_plot_ypred(xvar):
    rows,cols =1,3 
    fig, axes = plt.subplots(rows, cols, figsize=(6,6))
   
    imdat = X_test[xvar].reshape((64,-1))
    axes[0].imshow(np.flip(imdat,0),cmap='gray')
    axes[0].axis("off")

    corrin=y_pred[xvar]
    fhout=open('corr.in','w')
    fhout.write("%.6f %.6f\n%.6f %.6f\n"%(1.0,corrin[0],corrin[1],corrin[2]))
    fhout.close()
    calc_diffuse(iconc,1,icycles,ianneal,1) # do the regen on the image  
    
    occ3D=get_occ_map('./expfiles_1/ising2D_occ.txt')
    axes[1].imshow(np.transpose(occ3D[:,:,0]),interpolation='nearest',cmap='gray') 
    axes[1].axis("off")
    imdat = read_bin('./expfiles_1/hk0.bin', npixels=64, offset=1280)
    axes[2].imshow(np.flip(imdat,0),cmap='gray')
    axes[2].axis("off")
    
    my_metrics=get_metrics_compare_regens_test_set(xvar)
    my_metrics2=get_metrics_ypred_ytest(xvar)
  
    fig.suptitle("metrics(r2, mse, mae)\n corrfunc: %.3f, %.3f, %.3f \n FT_metrics: %.3f, %.3f, %.3f" %tuple(my_metrics) + "\n corrfunc test vs. pred: %.3f, %.3f, %.3f" %(my_metrics2[0], my_metrics2[1], my_metrics2[2]), fontsize=10, y=0.73)

# %%
#### might have to block average these metrics to get a better variance 
#### wonder what happens when i put other types of images into the model

# %%
xvar=np.random.randint(0,np.shape(X_test)[0],1)[0]
update_plot_regen(xvar)

# %%
update_plot_ypred(xvar)

# %%
print(" metrics(r2, mse, mae)\n corrfunc test vs. pred: %.3f, %.3f, %.3f \n " %(tuple(get_metrics_ypred_ytest(xvar))))
# Out:
#  metrics(r2, mse, mae)
#  corrfunc test vs. pred: 0.996, 0.001, 0.025
